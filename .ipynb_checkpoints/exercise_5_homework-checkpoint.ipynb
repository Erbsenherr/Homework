# %% [markdown]
# __Graph Databanks and Knowledge Graphs in Life Sciences - Python-Exercise__
#
# ***
#
# # Exercise 5: Querying RDFs with SPARQL
# ***

# %% [markdown]
# Name:
# <br>
# Matrikel-Nr.:
# ***

# %% [markdown]
# <div>
#      <img src="./figures/uniprotSPARQL_Endpoint.jpg" width=70%/>
# </div>
# <br> <br>
# Uniprot/Swissprot is a common knowledgebase containing information about proteins providing an endpoint for SPARQL queries at https://sparql.uniprot.org/uniprot. The figure shows the main concepts of the linked data in the Uniprot database, further subgraphs and their properties as well as links to external databases can be inspected at https://sparql.uniprot.org/.well-known/void.

# %% [markdown]
# # Task 1:
# > How many reviewed human proteins are present in the Uniprot knowlegdebase?

# %%
...

# %% [markdown]
# # Task 2:
# > Show 10 of those proteins and their E.C. number, if they have one assigned.

# %%
...

# %% [markdown]
# # Task 3:
# > How many different E.C. numbers are annotated to these reviewed human proteins?

# %%
...

# %% [markdown]
# # Task 4:
# > Please retrieve the full and short name of the protein with accession Q9HC29 using property paths.

# %%
...

# %% [markdown]
# # Task 5:
# > Please retrieve the titles of all Journal citations linked to this protein ordered by their date of publishing.

# %%
...

# %% [markdown]
# # Task 6:
# > Please retrieve the name of the disease, which the protein is annotated to.

# %%
...

# %% [markdown]
# # Task 7:
# > Look up `DESCRIBE` in the SPARQL Documentation and describe what it does:

# %% [markdown]
# ...

# %% [markdown]
# > Write a query to desribe the resource Aragor and execute it on the dbpedia website. <br>
# > What are the results?

# %% [markdown]
# ...

# %% [markdown]
# > Copy your query below:

# %%
...
